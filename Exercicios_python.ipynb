# %% [markdown]
# <a href="https://colab.research.google.com/github/LaraSampaio20/Python/blob/main/Exercicios_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 001 - Faça um programa em que ele leia  um numero inteiro e mostre o seu sucessor e o seu antecessor.

# %%
numero = int(input('Digite o numero aqui: '))
print(f'O numero escolhido é o {numero}, o seu sucessor é {numero + 1} e o seu antecessor é {numero - 1}')
# Out:
# Digite o numero aqui: 50
# O numero escolhido é o 50, o seu sucessor é 51 e o seu antecessor é 49

# %% [markdown]
# 002- Crie um algoritimo em que ele leia um numero e mostre:
#
#
# *   Dobro
# *   Triplo
# *   Raiz quadrada

# %%
num = int(input("Digite um numero: "))
print(f'O numero escolhido foi {num}.O dobro dele é {num*2}, o triplo é { num*3} e sua raiz quadrada é {num**(1/2):.2f}')
# Out:
# Digite um numero: 65
# O numero escolhido foi 65.O dobro dele é 130, o triplo é 195 e sua raiz quadrada é 8.06

# %% [markdown]
# 003 - Escreva duas notas de duas alunas e traga a media delas

# %%
nota1 = int(input('nota 1: '))
nota2 = int(input('nota 2: '))
print(f'Nota 1 foi de {nota1} e a nota nota 2 foi de {nota2}. Portanto a média é de {(nota1 + nota2)/2}')
# Out:
# nota 1: 5
# nota 2: 10
# Nota 1 foi de 5 e a nota nota 2 foi de 10. Portanto a média é de 7.5

# %% [markdown]
# 004- Escreva um programa em que leia um numero em metros e retorne em centimetros e milimetros.

# %%
metro = int(input('Qual o metro? '))
print(f'O metro é de {metro}, em centimetros é de {metro*100} e em milimetro é de {(metro*100)*10}')
# Out:
# Qual o metro? 50
# O metro é de 50, em centimetros é de 5000 e em milimetro é de 50000

# %% [markdown]
# 005 - Faça um programa que leia um numero inteiro na tela e mostre a sua tabuada.

# %%
num = int(input('Escolha um numero:'))
for i in range(0+11):
  print(f'A tabuada do numero {num} é: {num} x {i} = ')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2573048894.py in <cell line: 0>()
# ----> 1 num = int(input('Escolha um numero:'))
#       2 for i in range(0+11):
#       3   print(f'A tabuada do numero {num} é: {num} x {i} = ')
#       4
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#    1217             except KeyboardInterrupt:
#    1218                 # re-raise KeyboardInterrupt, to truncate traceback
# ...

# %% [markdown]
# 006 - Crie um programa que leia quanto de dinehiro a pessoa tem e mostre na tela quantos dolares ela pode comprar.
# * Us$ 1,00 = 3,27

# %%
carteira = int(input('Quanto possui na carteira?'))
print(f'Tenho na carteira {carteira} e posso comprar {carteira / 3.27:.2f} dolares')
# Out:
# Quanto possui na carteira?5000
# Tenho na carteira 5000 e posso comprar 1529.05

# %% [markdown]
# 007 - Faça um programa que mostre na tela a largura e a altura de uma parede em metros. Calcule sua área  e a quantidade de tinta necessária para pinta la, sabendo que cada litro de tinta pinta uma area de 2m

# %%
altura = int(input('Qual a altura da parede? '))
largura = int(input('Qual a largura da parede '))

area = altura * largura

T = area / 2

print(f'A altura da paede é de {altura}M e sua largura é de {largura}M.\nConsiderando sua area que é de {area}M, você irá precisaa de {T:.2f} litros de tinta para pintar.')
# Out:
# Qual a altura da parede? 3
# Qual a largura da parede 3
# A altura da paede é de 3M e sua largura é de 3M.
# Considerando sua area que é de 9M, você irá precisaa de 4.50 litros de tinta para pintar.

# %% [markdown]
# 008 -Faça um algoritimo que mostre o preço de um produto e mostre o seu novo preço com 5% de desconto.

# %%
produto = int(input('Preço do produto: '))

valor =  produto * 0.05

preco_final = produto - valor
print(f'O valor do seu produto é de {produto} reais e com 5% de desconto você irá pagar {preco_final} reais.')
# Out:
# Preço do produto: 250
# O valor do seu produto é de 250 reais e com 5% de desconto você irá pagar 237.5 reais.

# %% [markdown]
# 009 - Faça um algoritimo que mostre o salario de um funcionário e mostre o seu novo salario com 15% de aumento.

# %%
salario = int(input('Qual o salário de seu funcionário? '))

aumento = salario * 0.15

salario_final = salario + aumento
print(f'Seu salário era de {salario:.2f} reais e com o aumento de 15% o seu novo salário é de {salario_final:.2f} reais!')
# Out:
# Qual o salário de seu funcionário? 1550
# Seu salário era de 1550.00 reais e com o aumento de 15% o seu novo salário é de 1782.50 reais!

# %% [markdown]
# 010 - Escreva um programa que converta uma temperatura digitando em graus Celsius e converta para graus Fahrenheit.

# %%
c = float(input('Informe a temperatura em C: '))

# Calculo para transformar Ceusius em Fahrenheit
f = ((9 * c) /5) + 32

print(f'Atemperatura em Celsius é de {c} e convertida em Fahrenheit é de {f}.')
# Out:
# Informe a temperatura em C: 32
# Atemperatura em Celsius é de 32.0 e convertida em Fahrenheit é de 89.6.

# %% [markdown]
# 011- Escreva um programa que pergunte a quantidade de Km percorridos por um carro alugado e a quantidade de dias pelos quais ele foi alugado. Calcule o preço a pagar, sabendo que:
#
#  * O carro custa60 Reais por dia
#  * 0,15 Centavos por Km rodado.

# %%
km = float(input('Quantos Km você rodou com esse carro? '))
aluguel = int(input('Por quantos dias você alugou? '))
calc_dia = aluguel * 60
calc_km = km * 0.15
calc_final = calc_dia + calc_km

print(f'Você rodou por {km} Km e alugou por {aluguel} dias. O total a pagar é de R${calc_final:.2f}')
# Out:
# Quantos Km você rodou com esse carro? 30
# Por quantos dias você alugou? 15
# Você rodo por 30.0 Km e alugou por 15 dias. O total a pagar é de R$904.5

# %% [markdown]
# 012 - Crie um programa que leia um número Real qualquer pelo teclado e mostre na tela a sua porção Inteira.

# %%
import math

num = float(input('Digite um numero qualquer: '))

print('O numero que você digitou é {} e sua parte inteira é {}'. format(num, math.trunc(num)))
# Out:
# Digite um numero qualquer: 33.254856214
# O numero que você digitou é 33.254856214 e sua parte inteira é 33

# %% [markdown]
# 013-  Faça um programa que leia o comprimento do cateto oposto e do cateto adjacente de um triângulo retângulo. Calcule e mostre o comprimento da hipotenusa.

# %%
import math

ca =  float(input('Qual o seu cumprimento? '))
adj = float(input('Qual o seu cumprimento adj? '))

s = pow(ca, 2) + pow(adj, 2)
h = s**(1/2)

print('O cumprimento do cateto oposto é de {} e o cumprimento do adjacente é de {}. O cumprimento da hipotenusa é {:.2f}'.format(ca, adj,h))
# Out:
# Qual o seu cumprimento? 33
# Qual o seu cumprimento adj? 40
# O cumprimento do cateto oposto é de 33.0 e o cumprimento do adjacente é de 40.0. O cumprimento da hipotenusa é 51.86

# %% [markdown]
# 014 - Faça um programa que leia um ângulo qualquer e mostre na tela o valor do seno, cosseno e tangente desse ângulo.

# %%
#import math

ang = int(input('Digite um angulo: '))

s = math.sin(ang)
c = math.cos(ang)
t = math.tan(ang)
at = math.atan(ang)

print('O ângulo digitado é de {}, portanto o seu seno é de {:.2}, seu cosseno é de {:.2f} e sua tangente é de {:.2f}, e seu arcotangente é {:.2f}'.format(ang, s, c, t, at))
# Out:
# Digite um angulo: 90
# O ângulo digitado é de 90, portanto o seu seno é de 0.89, seu cosseno é de -0.45 e sua tangente é de -2.00, e seu arcotangente é 1.56

# %% [markdown]
# 015- Um professor quer sortear um dos seus quatro alunos para apagar o quadro. Faça um programa que ajude ele, lendo o nome dos alunos e escrevendo na tela o nome do escolhido.

# %%
import random

professor = random.choice

alunos = ['Anna', 'Lara', 'Pedro','Jeferson']



print('Temos hoje para apagar o quadro: A Anna,a Lara, o Pedro e o Jeferson. E o escolhido é: {}!!!'.format(random.choice(alunos)))
# Out:
# Temos hoje para apagar o quadro: A Anna,a Lara, o Pedro e o Jeferson. E o escolhido é: Lara !!!

# %% [markdown]
# O mesmo professor do desafio aacima quer sortear a ordem de apresentação de trabalhos dos alunos. Faça um programa que leia o nome dos quatro alunos e mostre a ordem sorteada.

# %%
import random

professor1 = random.sample

alunos = ['Anna', 'Lara', 'Pedro','Jeferson']


print('Hoje teremos a apresentação dos trabalhos e  ordem escolhida é: {}'.format(random.sample(alunos, k=4)))
# Out:
# Hoje teremos a apresentação dos trabalhos e  ordem escolhida é: ['Pedro', 'Jeferson', 'Anna', 'Lara']

# %% [markdown]
# 016- Faça um programa em Python que abra e reproduza o áudio de um arquivo MP3.

# %%
# %pip install pygame

# %%
import pygame
pygame.init()
pygame.mixer.music.load('musica.mp3')
pygame.mixer.music.play()
pygame.event.wait()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# /tmp/ipython-input-2216207389.py in <cell line: 0>()
#       1 import pygame
#       2 pygame.init()
# ----> 3 pygame.mixer.music.load('musica.mp3')
#       4 pygame.mixer.music.play()
#       5 pygame.event.wait()
#
# error: mixer not initialized

# %% [markdown]
# 017- Crie um programa que leia o nome completo de uma pessoa e mostre:
#
# – O nome com todas as letras maiúsculas e minúsculas.
#
# – Quantas letras ao todo (sem considerar espaços).
#
# – Quantas letras tem o primeiro nome.

# %%
nome = input('Qual o seu nome completo? ')


print(f'Maiusculo: {nome.upper()}. Minusculo: {nome.lower()}. Qtd: {len(nome.strip())}. {len("Lara")}')
# Out:
# Qual o seu nome completo? Lara Fernanda Sampaio da Silva
# Maiusculo: LARA FERNANDA SAMPAIO DA SILVA. Minusculo: lara fernanda sampaio da silva. Qtd: 30. 4

# %% [markdown]
# 018 - Faça um programa que leia um número de 0 a 9999 e mostre na tela cada um dos dígitos separados.

# %%
num= input('Digite um numero de 0 a 9999: ')


print(num.split())
# Out:
# Digite um numero de 0 a 9999: 3,25,36,2
# ['3,25,36,2']

# %% [markdown]
# 019- Crie um programa que leia o nome de uma cidade diga se ela começa ou não com o nome “SANTO”.

# %%
cidade = input('Escreva o nome de uma cidade: ')

print(f'Essa cidade começa com SANTO? {"SANTO" in cidade[0]}')
# Out:
# Escreva o nome de uma cidade: PADROEIRO DO SANTO
# Essa cidade começa com SANTO? False

# %% [markdown]
# 020-  Crie um programa que leia o nome de uma pessoa e diga se ela tem “SILVA” no nome.

# %%
nome = input('Digite um nome: ')

print(f'Essa pessoa contem SILVA no nome? {"SILVA" in nome}')
# Out:
# Digite um nome: Lara Fernanda Sampaio da SILVA
# Essa pessoa contem SILVA no nome? True

# %% [markdown]
# 021- Faça um programa que leia uma frase pelo teclado e mostre quantas vezes aparece a letra “A”, em que posição ela aparece a primeira vez e em que posição ela aparece a última vez.

# %%
frase = str(input('Digite uma frase: ')).upper()

print(f'A frase possui {len(frase)} caracteries.')
print(f'Quantas vezes aparece a letra? Aparece {frase.count("A")} vezes.')
print(f'A letra A aparece na posição: {frase.find("A")+1}')
print(f'A ultima letra A aparece na posição: {frase.rfind("A")+1}')
# Out:
# Digite uma frase: Arara Azul da Amazonia
# A frase possui 22 caracteries.
# Quantas vezes aparece a letra? Aparece 8 vezes.
# A letra A aparece na posição: 1
# A ultima letra A aparece na posição: 22

# %% [markdown]
# 022- Faça um programa que leia o nome completo de uma pessoa, mostrando em seguida o primeiro e o último nome separadamente.

# %%
d = str(input('Digite seu nome completo: '))

nome = d.split()

print(f'O seu primeiro nome é {nome[0]}')
print(f'O seu ultimo nome é {nome[len(nome)-1]}')
# Out:
# Digite seu nome completo: Lara Fernanda Sampaio da Silva
# O seu primeiro nome é Lara
# O seu ultimo nome é Silva

# %% [markdown]
# 023- Escreva um programa que faça o computador “pensar” em um número inteiro entre 0 e 5 e peça para o usuário tentar descobrir qual foi o número escolhido pelo computador. O programa deverá escrever na tela se o usuário venceu ou perdeu.

# %%
from random import randint
itens = [0,1,2,3,4,5]

resultado = []

computador = randint(0,6)

user = int(input('Digite um numero'))

print('-=' * 11)
print('O computador escolheu {} '.format(itens[computador]))
print('Você escolheu {}'.format(itens[user]))
print('-=' * 11)

if (computador == 0 and user == 0) or (computador == 1 and user == 1) or (computador == 2 and user == 2)  or (computador == 3 and user == 3) or (computador == 4 and user == 4) or (computador == 5 and user == 5):
              print('Parabéns, você acertou o numero que o computador estava pensando!!')
else :
              print('Não foi dessa vez que você ganhou super poderes de adivinhação!! Tente novamente.')
              resultado.append(1)
# Out:
# Digite um numero5
# -=-=-=-=-=-=-=-=-=-=-=
# O computador escolheu 2
# Você escolheu 5
# -=-=-=-=-=-=-=-=-=-=-=
# Não foi dessa vez que você ganhou super poderes de adivinhação!! Tente novamente.

# %% [markdown]
# 024 - Escreva um programa que leia a velocidade de um carro. Se ele ultrapassar 80Km/h, mostre uma mensagem dizendo que ele foi multado. A multa vai custar R$7,00 por cada Km acima do limite.

# %%
velocidade = int(input('Qual é a velocidade atingida? '))

multa = (velocidade - 80) * 7

if velocidade > 80:
  print(f'sua multa por ultrapassagem é de {multa} reais..')

else:
  print('Você está dentro das normas de transito.')
# Out:
# Qual é a velocidade atingida? 100
# sua multa por ultrapassagem é de 140 reais..

# %% [markdown]
# 025- Crie um programa que leia um número inteiro e mostre na tela se ele é PAR ou ÍMPAR.
#
# Aula Anterior

# %%
numero = int(input('Digite um numero: '))

if numero %2 == 0:
  print(f'O numero {numero}  é par' )
else:
  print(f'O numero {numero} é impar')
# Out:
# Digite um numero: 6
# O numero 6  é par

# %% [markdown]
# 026- Desenvolva um programa que pergunte a distância de uma viagem em Km. Calcule o preço da passagem, cobrando 0,50 por Km para viagens de até 200Km e R$0,45 parta viagens mais longas.

# %%
distancia = int(input('Distancia: '))


if distancia <= 200:
  print(f'Para essa distancia o valor é de {distancia * 0.50} reais.')
else:
  print(f'Para essa distancia o valor é de {distancia * 0.45} reais.')
# Out:
# Distancia: 500
# Para essa distancia o valor é de 225.0 reais.

# %% [markdown]
# 027- Faça um programa que leia um ano qualquer e mostre se ele é bissexto.

# %%
ano = int(input('Qual ano gostaria de analisar? '))

if ano % 4 == 0:
  print(f'O de {ano} é Bissexto!')
else:
  print(f'O de {ano} é comum!')
# Out:
# Qual ano gostaria de analisar? 2025
# O de 2025 é comum!

# %% [markdown]
# 028- Faça um programa que leia três números e mostre qual é o maior e qual é o menor.

# %%
a = input('Valor 1: ')
b = input('Valor 2: ')
c = input('Valor 3: ')
menor = a

if b<a and b<c:
  menor = b
if c<a and c<b:
  menor = c
maior = a

if b>a and b>c:
  maior = b
if c>a and c>b:
  maior = c

  print(f'O maior numero é o {maior} e o menor numero é o {menor}.')
# Out:
# Valor 1: 1
# Valor 2: 7
# Valor 3: 8
# O maior numero é o 8 e o menor numero é o 1.

# %% [markdown]
# 029- Escreva um programa que pergunte o salário de um funcionário e calcule o valor do seu aumento. Para salários superiores a R$1250,00, calcule um aumento de 10%. Para os inferiores ou iguais, o aumento é de 15%.

# %%
salario = float(input('Qual é o seu salário? '))

if salario > 1250.00:
  print(f'O seu salário teve um aumento de 10%, portanto seu salário é de {(salario * 0.10) + salario} reais')
else:
  print(f'O seu salário teve um aumento de 15%, portanto seu salário é de {(salario * 0.15) + salario} reais.')
# Out:
# Qual é o seu salário ?1250
# O seu salário teve um aumento de 15%, portanto seu salário é de 1437.5 reais.

# %% [markdown]
# 030- Desenvolva um programa que leia o comprimento de três retas e diga ao usuário se elas podem ou não formar um triângulo.

# %%
print('Analisando a formação de um triangulo')
print('>='*25)

l1 = float(input('Valor 1: '))
l2 = float(input('Valor 2: '))
l3 = float(input('Valor 3: '))

if l1 < l2 + l3 and l2 < l1+ l3 and l3 <l1 + l2:
  print(f'O seguimentos {l1}, {l2} e {l3} podem formar um triangulo.')
else:
  print(f'O seguimentos {l1}, {l2} e {l3} não podem formar um triangulo. Tente novamente.')
# Out:
# Analisando a formação de um triangulo
# >=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=>=
# Valor 1: 4
# Valor 2: 6
# Valor 3: 2
# O seguimentos 4.0, 6.0 e 2.0 não podem formar um triangulo. Tente novamente.

# %% [markdown]
# 031- Escreva um codigo par aparovar um empréstimo bancario para a compra de um imóvel
# - Precisa ter o valor do imovel, o salario, e em quantos anos quer pagar
# - É necessário calcular o valor sobre as parcelas, sabendo que nao pode ultrapassar de 30% do salario

# %%
#Variavéis
casa = int(input("Qual o valor da casa a ser comprada? "))

salario = int(input("Qual o seu salário? "))

parcelas = int(input("Em quantas parcelas deseja pagar? "))

parcela_mensal = casa / parcelas

porc_salario = (salario * 30) / 100

if parcela_mensal > porc_salario:
  print(f"O valor das parcalas mensal é de {parcela_mensal:.2f}. \na porcentagem correspondente aos 30% do seu salário é {porc_salario:.2f}.\nSendo assim: Empréstimo não aprovado")
elif parcela_mensal == porc_salario:
  print(f"Empréstimo em analise. O valor mensal é de {parcela_mensal:.2f},\na porcentagem correspondente aos 30% do seu salário é {porc_salario:.2f}.")
else:
  print(f"O valor das parcalas mensal é de {parcela_mensal:.2f}. Já a porcentagem correspondente aos 30% do seu salário é {porc_salario:.2f}.\nSendo assim: Empréstimo aprovado!!!")


#Teste de calculo mensal das parcelas
# print(f"{valor_mensal:.2f}")

# %% [markdown]
# 032-  Faça uma comparação de numeros, usando IF Elif e Else

# %%
num1 = int(input("Insira o primeiro numero:" ))
num2 = int(input("Insira o segundo numero:" ))

if num1 > num2:
  print(f"O numero {num1} é maior!")

elif num2 > num1:
  print(f"O numero {num2} é maior!")

else:
  print("Não existe valor maior, o dois são iguais!!!")

# %% [markdown]
# 033- A instrução if not em Python serve para executar um bloco de código quando uma condição é falsa ou
# quando um objeto é considerado "falsy" como uma lista vazia ou zero).
# Ela é utilizada para verificar a ausência de algo,
# negando o resultado de uma expressão lógica ou a "verdade" de um valor,
# tornando o código mais conciso e legível para verificar cenários negativos.

# %%
Escolha o tipo de conversao com comparacoes

escolha = input("Escolha o tipo da conversão que deseja fazer?" )


if not escolha:
  print("Por favor, insira um valor.")
elif not escolha.isdigit():
  print("Entrada inválida. Por favor, insira um número inteiro.")
else:
  escolha = int(escolha)
  if escolha == 1:
    print("Você escolheu o tipo Binário!")

  elif escolha == 2:
    print("Você escolheu o tipo Octal!")

  elif escolha == 3:
    print("Você escolheu o tipo Hexadecimal!")

  elif escolha <= 0:
    print("Escolha uma das opções para continuar.")

  else:
    print("escolha uma das opções")

# %% [markdown]
# 035- Faça um programa que leia o ano de nascimento de um jovem e informe, de acordo com a sua idade, se:
#
# - Ele ainda vai se alistar ao serviço militar; se:
# - É a hora exata de se alistar e se:
# - Já passou do tempo do alistamento.
#
# **Seu programa também deverá mostrar o tempo que falta ou que passou do prazo.**

# %%
jovem = int(input('Qual o ano do seu nascimento? '))

ano_atual = int(input('Ano atual: '))

tempo = ano_atual - 18
tempo_p = ano_atual + 18

if jovem > 2007:
  print(f'Ele ainda irá se alistar. Faltam {tempo_p} anos para o seu alistamento.')
elif jovem == 2007:
  print('É a hora exata de se alistar')
else:
  print(f'Já passou o seu tempo de alistamento. O prazo era de {tempo} anos atrás.')
# Out:
# Qual o ano do seu nascimento? 2010
# Ano atual: 2025
# Ele ainda irá se alistar. Faltam 2043 anos para o seu alistamento.

# %% [markdown]
# 036- Crie um programa que leia duas notas de um aluno e calcule sua média, mostrando uma mensagem no final, de acordo com a média atingida:
#
# - Média abaixo de 5.0: REPROVADO
#
# -  Média entre 5.0 e 6.9: RECUPERAÇÃO
#
# - Média 7.0 ou superior: APROVADO

# %%
n1 = float(input('Primeira nota: '))
n2 = float(input('Segunda nota: '))

nota_final = (n1 + n2)/2

if nota_final < 5.0:
  print(f'Sua nota foi de {nota_final}. Você está reprovada!')
elif nota_final >= 5.0 and nota_final <= 6.9:
  print(f'Sua nota foi de {nota_final}. Você ficará de recuperação!')
else:
  print(f'Sua nota foi de {nota_final}. Parabéns, você foi aprovado!!!')
# Out:
# Primeira nota: 7
# Segunda nota: 6
# Sua nota foi de 6.5. Você ficará de recuperação!

# %% [markdown]
# 037- A Confederação Nacional de Natação precisa de um programa que leia o ano de nascimento de um atleta e mostre sua categoria, de acordo com a idade:
#
# - Até 9 anos: MIRIM
#
# - Até 14 anos: INFANTIL
#
# - Até 19 anos: JÚNIOR
#
# - Até 25 anos: SÊNIOR
#
# - Acima de 25 anos: MASTER

# %%
ano_nascimento = int(input('Qual sua idade? '))

if

# %% [markdown]
# 038- Refaça o DESAFIO 35 dos triângulos, acrescentando o recurso de mostrar que tipo de triângulo será formado:
#
# - EQUILÁTERO: todos os lados iguais
#
# - ISÓSCELES: dois lados iguais, um diferente
#
# - ESCALENO: todos os lados diferentes

# %% [markdown]
# 039- Desenvolva uma lógica que leia o peso e a altura de uma pessoa, calcule seu Índice de Massa Corporal (IMC) e mostre seu status, de acordo com a tabela abaixo:
#
# - IMC abaixo de 18,5: Abaixo do Peso
#
# - Entre 18,5 e 25: Peso Ideal
#
# - 25 até 30: Sobrepeso
#
# - 30 até 40: Obesidade
#
# - Acima de 40: Obesidade Mórbida

# %% [markdown]
# 040- Elabore um programa que calcule o valor a ser pago por um produto, considerando o seu preço normal e condição de pagamento:
#
# - à vista dinheiro/cheque: 10% de desconto
#
# - à vista no cartão: 5% de desconto
#
# - em até 2x no cartão: preço formal
#
# - 3x ou mais no cartão: 20% de juros
